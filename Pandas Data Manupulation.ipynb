# %% [markdown]
# # Pandas Data Manupulation

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Sample Data

# %%
df = pd.DataFrame(np.random.rand(6,4),
                 index=['one', 'two', 'three', 'four', 'five', 'six'],
                 columns=pd.Index(['A', 'B', 'C', 'D'],
                                 name='Genus'))

# %%
df
# Out:
# Genus         A         B         C         D
# one    0.492046  0.337521  0.285384  0.254196
# two    0.518255  0.565217  0.240256  0.616309
# three  0.858079  0.085495  0.206723  0.391890
# four   0.518553  0.588534  0.088025  0.494588
# five   0.228180  0.950215  0.584908  0.693443
# six    0.897482  0.828880  0.777449  0.280362

# %%
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Statistic Calculation
# https://pandas.pydata.org/pandas－docs/stable/reference/api/pandas.DataFrame.max.htmlhttps://pandas.pydata.org/pandas－docs/stable/referhttps://pandas.pydata.org/pandas－docs/stable/refer

# %% [markdown]
# ### Extract the max value for each column

# %%
df.max()
# Out:
# Genus
# A    0.897482
# B    0.950215
# C    0.777449
# D    0.693443
# dtype: float64

# %% [markdown]
# ### Extract the max value of one specific column

# %%
df.max()
# Out:
# Genus
# A    0.897482
# B    0.950215
# C    0.777449
# D    0.693443
# dtype: float64

# %% [markdown]
# ### Extract the max value of a specific column

# %%
df['A'].max() # Max of "A' column
# Out:
# 0.8974820112119557

# %% [markdown]
# ## Add new column

# %%
df['E'] = np.nan

# %%
df
# Out:
# Genus         A         B         C         D   E
# one    0.492046  0.337521  0.285384  0.254196 NaN
# two    0.518255  0.565217  0.240256  0.616309 NaN
# three  0.858079  0.085495  0.206723  0.391890 NaN
# four   0.518553  0.588534  0.088025  0.494588 NaN
# five   0.228180  0.950215  0.584908  0.693443 NaN
# six    0.897482  0.828880  0.777449  0.280362 NaN

# %%
# df['E'] = 0.0

# %%
# df

# %%
### Identify maximun value and put on column 'MAX'

# %%
df['MAX'] = df.T.max()

# %%
df
# Out:
# Genus         A         B         C         D   E       MAX
# one    0.492046  0.337521  0.285384  0.254196 NaN  0.492046
# two    0.518255  0.565217  0.240256  0.616309 NaN  0.616309
# three  0.858079  0.085495  0.206723  0.391890 NaN  0.858079
# four   0.518553  0.588534  0.088025  0.494588 NaN  0.588534
# five   0.228180  0.950215  0.584908  0.693443 NaN  0.950215
# six    0.897482  0.828880  0.777449  0.280362 NaN  0.897482

# %%
df['ID'] = np.arange(6.)

# %%
df
# Out:
# Genus         A         B         C         D   E       MAX   ID
# one    0.492046  0.337521  0.285384  0.254196 NaN  0.492046  0.0
# two    0.518255  0.565217  0.240256  0.616309 NaN  0.616309  1.0
# three  0.858079  0.085495  0.206723  0.391890 NaN  0.858079  2.0
# four   0.518553  0.588534  0.088025  0.494588 NaN  0.588534  3.0
# five   0.228180  0.950215  0.584908  0.693443 NaN  0.950215  4.0
# six    0.897482  0.828880  0.777449  0.280362 NaN  0.897482  5.0

# %% [markdown]
# ### Identify Delta value and put on column 'x'

# %%
df.T.min()
# Out:
# one      0.000000
# two      0.240256
# three    0.085495
# four     0.088025
# five     0.228180
# six      0.280362
# dtype: float64

# %%
df['x'] = df.T.min()

# %%
df
# Out:
# Genus         A         B         C         D   E       MAX   ID         x
# one    0.492046  0.337521  0.285384  0.254196 NaN  0.492046  0.0  0.000000
# two    0.518255  0.565217  0.240256  0.616309 NaN  0.616309  1.0  0.240256
# three  0.858079  0.085495  0.206723  0.391890 NaN  0.858079  2.0  0.085495
# four   0.518553  0.588534  0.088025  0.494588 NaN  0.588534  3.0  0.088025
# five   0.228180  0.950215  0.584908  0.693443 NaN  0.950215  4.0  0.228180
# six    0.897482  0.828880  0.777449  0.280362 NaN  0.897482  5.0  0.280362
