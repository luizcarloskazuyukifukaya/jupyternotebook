# %% [markdown]
# # Pandas Data Manupulation

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Sample Data

# %%
df = pd.DataFrame(np.random.rand(6,4),
                 index=['one', 'two', 'three', 'four', 'five', 'six'],
                 columns=pd.Index(['A', 'B', 'C', 'D'],
                                 name='Genus'))

# %%
df
# Out:
# Genus         A         B         C         D
# one    0.350335  0.895428  0.338071  0.779077
# two    0.527625  0.597995  0.726427  0.884034
# three  0.238324  0.809554  0.145014  0.385073
# four   0.550149  0.008513  0.934165  0.290140
# five   0.357724  0.573810  0.912258  0.279726
# six    0.136611  0.180384  0.086970  0.219781

# %%
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Statistic Calculation
# https://pandas.pydata.org/pandas－docs/stable/reference/api/pandas.DataFrame.max.htmlhttps://pandas.pydata.org/pandas－docs/stable/referhttps://pandas.pydata.org/pandas－docs/stable/refer

# %% [markdown]
# ### Extract the max value for each column

# %%
df.max()
# Out:
# Genus
# A    0.550149
# B    0.895428
# C    0.934165
# D    0.884034
# dtype: float64

# %% [markdown]
# ### Extract the max value of one specific column

# %%
df.max()
# Out:
# Genus
# A    0.550149
# B    0.895428
# C    0.934165
# D    0.884034
# dtype: float64

# %% [markdown]
# ### Extract the max value of a specific column

# %%
df['A'].max() # Max of "A' column
# Out:
# 0.5501490555406002

# %% [markdown]
# ## Add new column

# %%
df['E'] = np.nan

# %%
df
# Out:
# Genus         A         B         C         D   E
# one    0.350335  0.895428  0.338071  0.779077 NaN
# two    0.527625  0.597995  0.726427  0.884034 NaN
# three  0.238324  0.809554  0.145014  0.385073 NaN
# four   0.550149  0.008513  0.934165  0.290140 NaN
# five   0.357724  0.573810  0.912258  0.279726 NaN
# six    0.136611  0.180384  0.086970  0.219781 NaN

# %%
# df['E'] = 0.0

# %%
# df

# %%
### Identify maximun value and put on column 'MAX'

# %%
df['MAX'] = df.T.max()

# %%
df
# Out:
# Genus         A         B         C         D   E       MAX
# one    0.350335  0.895428  0.338071  0.779077 NaN  0.895428
# two    0.527625  0.597995  0.726427  0.884034 NaN  0.884034
# three  0.238324  0.809554  0.145014  0.385073 NaN  0.809554
# four   0.550149  0.008513  0.934165  0.290140 NaN  0.934165
# five   0.357724  0.573810  0.912258  0.279726 NaN  0.912258
# six    0.136611  0.180384  0.086970  0.219781 NaN  0.219781

# %%
df['ID'] = np.arange(6.)

# %%
df
# Out:
# Genus         A         B         C         D   E       MAX   ID
# one    0.350335  0.895428  0.338071  0.779077 NaN  0.895428  0.0
# two    0.527625  0.597995  0.726427  0.884034 NaN  0.884034  1.0
# three  0.238324  0.809554  0.145014  0.385073 NaN  0.809554  2.0
# four   0.550149  0.008513  0.934165  0.290140 NaN  0.934165  3.0
# five   0.357724  0.573810  0.912258  0.279726 NaN  0.912258  4.0
# six    0.136611  0.180384  0.086970  0.219781 NaN  0.219781  5.0

# %% [markdown]
# ### Identify Delta value and put on column 'x'

# %%
df.T.min()
# Out:
# one      0.000000
# two      0.527625
# three    0.145014
# four     0.008513
# five     0.279726
# six      0.086970
# dtype: float64

# %%
df['x'] = df.T.min()

# %%
df
# Out:
# Genus         A         B         C         D   E       MAX   ID         x
# one    0.350335  0.895428  0.338071  0.779077 NaN  0.895428  0.0  0.000000
# two    0.527625  0.597995  0.726427  0.884034 NaN  0.884034  1.0  0.527625
# three  0.238324  0.809554  0.145014  0.385073 NaN  0.809554  2.0  0.145014
# four   0.550149  0.008513  0.934165  0.290140 NaN  0.934165  3.0  0.008513
# five   0.357724  0.573810  0.912258  0.279726 NaN  0.912258  4.0  0.279726
# six    0.136611  0.180384  0.086970  0.219781 NaN  0.219781  5.0  0.086970

# %%
df
# Out:
# Genus         A         B         C         D   E       MAX   ID         x
# one    0.350335  0.895428  0.338071  0.779077 NaN  0.895428  0.0  0.000000
# two    0.527625  0.597995  0.726427  0.884034 NaN  0.884034  1.0  0.527625
# three  0.238324  0.809554  0.145014  0.385073 NaN  0.809554  2.0  0.145014
# four   0.550149  0.008513  0.934165  0.290140 NaN  0.934165  3.0  0.008513
# five   0.357724  0.573810  0.912258  0.279726 NaN  0.912258  4.0  0.279726
# six    0.136611  0.180384  0.086970  0.219781 NaN  0.219781  5.0  0.086970

# %%
df.drop('ID', axis='columns')
# Out:
# Genus         A         B         C         D   E       MAX         x
# one    0.350335  0.895428  0.338071  0.779077 NaN  0.895428  0.000000
# two    0.527625  0.597995  0.726427  0.884034 NaN  0.884034  0.527625
# three  0.238324  0.809554  0.145014  0.385073 NaN  0.809554  0.145014
# four   0.550149  0.008513  0.934165  0.290140 NaN  0.934165  0.008513
# five   0.357724  0.573810  0.912258  0.279726 NaN  0.912258  0.279726
# six    0.136611  0.180384  0.086970  0.219781 NaN  0.219781  0.086970

# %%
df
# Out:
# Genus         A         B         C         D   E       MAX   ID         x
# one    0.350335  0.895428  0.338071  0.779077 NaN  0.895428  0.0  0.000000
# two    0.527625  0.597995  0.726427  0.884034 NaN  0.884034  1.0  0.527625
# three  0.238324  0.809554  0.145014  0.385073 NaN  0.809554  2.0  0.145014
# four   0.550149  0.008513  0.934165  0.290140 NaN  0.934165  3.0  0.008513
# five   0.357724  0.573810  0.912258  0.279726 NaN  0.912258  4.0  0.279726
# six    0.136611  0.180384  0.086970  0.219781 NaN  0.219781  5.0  0.086970

# %% [markdown]
# ## Inplace manupulation

# %%
df.drop(['ID','E'], axis='columns', inplace=True)
df
# Out:
# Genus         A         B         C         D       MAX         x
# one    0.350335  0.895428  0.338071  0.779077  0.895428  0.000000
# two    0.527625  0.597995  0.726427  0.884034  0.884034  0.527625
# three  0.238324  0.809554  0.145014  0.385073  0.809554  0.145014
# four   0.550149  0.008513  0.934165  0.290140  0.934165  0.008513
# five   0.357724  0.573810  0.912258  0.279726  0.912258  0.279726
# six    0.136611  0.180384  0.086970  0.219781  0.219781  0.086970

# %% [markdown]
# ## Change Index name

# %%
### df.reindex(columns=['A','B','C','D','MAX','MIN'])
df.reindex(columns=['A','B','C','D','MAX','MIN'])
# Out:
# Genus         A         B         C         D       MAX  MIN
# one    0.350335  0.895428  0.338071  0.779077  0.895428  NaN
# two    0.527625  0.597995  0.726427  0.884034  0.884034  NaN
# three  0.238324  0.809554  0.145014  0.385073  0.809554  NaN
# four   0.550149  0.008513  0.934165  0.290140  0.934165  NaN
# five   0.357724  0.573810  0.912258  0.279726  0.912258  NaN
# six    0.136611  0.180384  0.086970  0.219781  0.219781  NaN

# %% [markdown]
# - Column df['MIN'] is created with NaN because it does not exist.

# %% [markdown]
# ### Change Column index name

# %%
columns = df.columns
columns
# Out:
# Index(['A', 'B', 'C', 'D', 'MAX', 'x'], dtype='object', name='Genus')

# %%
index = df.index
index
# Out:
# Index(['one', 'two', 'three', 'four', 'five', 'six'], dtype='object')

# %%
# Rename column 'x' to 'MIN'
df.rename(columns={'x':'MIN'}, inplace=True)

# %%
df
# Out:
# Genus         A         B         C         D       MAX       MIN
# one    0.350335  0.895428  0.338071  0.779077  0.895428  0.000000
# two    0.527625  0.597995  0.726427  0.884034  0.884034  0.527625
# three  0.238324  0.809554  0.145014  0.385073  0.809554  0.145014
# four   0.550149  0.008513  0.934165  0.290140  0.934165  0.008513
# five   0.357724  0.573810  0.912258  0.279726  0.912258  0.279726
# six    0.136611  0.180384  0.086970  0.219781  0.219781  0.086970

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'MAX', 'MIN'], dtype='object', name='Genus')

# %%
df.loc[:,['B','D','MAX','MIN']]
# Out:
# Genus         B         D       MAX       MIN
# one    0.895428  0.779077  0.895428  0.000000
# two    0.597995  0.884034  0.884034  0.527625
# three  0.809554  0.385073  0.809554  0.145014
# four   0.008513  0.290140  0.934165  0.008513
# five   0.573810  0.279726  0.912258  0.279726
# six    0.180384  0.219781  0.219781  0.086970

# %%
df
# Out:
# Genus         A         B         C         D       MAX       MIN
# one    0.350335  0.895428  0.338071  0.779077  0.895428  0.000000
# two    0.527625  0.597995  0.726427  0.884034  0.884034  0.527625
# three  0.238324  0.809554  0.145014  0.385073  0.809554  0.145014
# four   0.550149  0.008513  0.934165  0.290140  0.934165  0.008513
# five   0.357724  0.573810  0.912258  0.279726  0.912258  0.279726
# six    0.136611  0.180384  0.086970  0.219781  0.219781  0.086970

# %%
df.drop('MIN', axis='columns', inplace=True)

# %%
df
# Out:
# Genus         A         B         C         D       MAX
# one    0.350335  0.895428  0.338071  0.779077  0.895428
# two    0.527625  0.597995  0.726427  0.884034  0.884034
# three  0.238324  0.809554  0.145014  0.385073  0.809554
# four   0.550149  0.008513  0.934165  0.290140  0.934165
# five   0.357724  0.573810  0.912258  0.279726  0.912258
# six    0.136611  0.180384  0.086970  0.219781  0.219781

# %%
df.shape
# Out:
# (6, 5)

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'MAX'], dtype='object', name='Genus')

# %%
df.index
# Out:
# Index(['one', 'two', 'three', 'four', 'five', 'six'], dtype='object')

# %%
df.min()
# Out:
# Genus
# A      0.136611
# B      0.008513
# C      0.086970
# D      0.219781
# MAX    0.219781
# dtype: float64

# %%
df['MIN'] = df.T.min()

# %%
df
# Out:
# Genus         A         B         C         D       MAX       MIN
# one    0.350335  0.895428  0.338071  0.779077  0.895428  0.338071
# two    0.527625  0.597995  0.726427  0.884034  0.884034  0.527625
# three  0.238324  0.809554  0.145014  0.385073  0.809554  0.145014
# four   0.550149  0.008513  0.934165  0.290140  0.934165  0.008513
# five   0.357724  0.573810  0.912258  0.279726  0.912258  0.279726
# six    0.136611  0.180384  0.086970  0.219781  0.219781  0.086970

# %% [markdown]
# ## SUM Calculations

# %% [markdown]
# ### SUM of index (sum of A, sum of B, Sum of C....)

# %%
df.sum(axis='index', skipna = True) #df.sum(axis=0, skipna = True)
# Out:
# Genus
# A      2.160767
# B      3.065685
# C      3.142904
# D      2.837830
# MAX    4.655220
# MIN    1.385918
# dtype: float64

# %% [markdown]
# ### SUM of column (Sum of one, Sum of two, Sum of three, ...)

# %%
df.sum(axis='columns', skipna = True) #df.sum(axis=1, skipna = True)
# Out:
# one      3.596409
# two      4.147739
# three    2.532532
# four     2.725645
# five     3.315501
# six      0.930497
# dtype: float64

# %% [markdown]
# ### TOTAL of columns by each index

# %%
df.loc[:,['A','B','C','D']]
# Out:
# Genus         A         B         C         D
# one    0.350335  0.895428  0.338071  0.779077
# two    0.527625  0.597995  0.726427  0.884034
# three  0.238324  0.809554  0.145014  0.385073
# four   0.550149  0.008513  0.934165  0.290140
# five   0.357724  0.573810  0.912258  0.279726
# six    0.136611  0.180384  0.086970  0.219781

# %%
df['TOTAL'] = df.loc[:,['A','B','C','D']].sum(axis='columns', skipna = True)

# %%
df
# Out:
# Genus         A         B         C         D       MAX       MIN     TOTAL
# one    0.350335  0.895428  0.338071  0.779077  0.895428  0.338071  2.362910
# two    0.527625  0.597995  0.726427  0.884034  0.884034  0.527625  2.736081
# three  0.238324  0.809554  0.145014  0.385073  0.809554  0.145014  1.577964
# four   0.550149  0.008513  0.934165  0.290140  0.934165  0.008513  1.782967
# five   0.357724  0.573810  0.912258  0.279726  0.912258  0.279726  2.123518
# six    0.136611  0.180384  0.086970  0.219781  0.219781  0.086970  0.623746

# %%
df.shape
# Out:
# (6, 7)

# %%
df.info
# Out:
# <bound method DataFrame.info of Genus         A         B         C         D       MAX       MIN     TOTAL
# one    0.350335  0.895428  0.338071  0.779077  0.895428  0.338071  2.362910
# two    0.527625  0.597995  0.726427  0.884034  0.884034  0.527625  2.736081
# three  0.238324  0.809554  0.145014  0.385073  0.809554  0.145014  1.577964
# four   0.550149  0.008513  0.934165  0.290140  0.934165  0.008513  1.782967
# five   0.357724  0.573810  0.912258  0.279726  0.912258  0.279726  2.123518
# six    0.136611  0.180384  0.086970  0.219781  0.219781  0.086970  0.623746>

# %%
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
