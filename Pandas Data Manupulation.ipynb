# %% [markdown]
# # Pandas Data Manupulation

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Sample Data

# %%
df = pd.DataFrame(np.random.rand(6,4),
                 index=['one', 'two', 'three', 'four', 'five', 'six'],
                 columns=pd.Index(['A', 'B', 'C', 'D'],
                                 name='Genus'))

# %%
df
# Out:
# Genus         A         B         C         D
# one    0.352693  0.450121  0.056892  0.777959
# two    0.458146  0.192793  0.532345  0.938560
# three  0.342202  0.112947  0.979487  0.108852
# four   0.028236  0.719497  0.954952  0.004119
# five   0.662823  0.924540  0.871982  0.926860
# six    0.513706  0.027894  0.228887  0.290175

# %%
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# ## Statistic Calculation
# https://pandas.pydata.org/pandas－docs/stable/reference/api/pandas.DataFrame.max.htmlhttps://pandas.pydata.org/pandas－docs/stable/referhttps://pandas.pydata.org/pandas－docs/stable/refer

# %% [markdown]
# ### Extract the max value for each column

# %%
df.max()
# Out:
# Genus
# A    0.662823
# B    0.924540
# C    0.979487
# D    0.938560
# dtype: float64

# %% [markdown]
# ### Extract the max value of one specific column

# %%
df.max()
# Out:
# Genus
# A    0.662823
# B    0.924540
# C    0.979487
# D    0.938560
# dtype: float64

# %% [markdown]
# ### Extract the max value of a specific column

# %%
df['A'].max() # Max of "A' column
# Out:
# 0.6628230578766066

# %% [markdown]
# ## Add new column

# %%
df['E'] = np.nan

# %%
df
# Out:
# Genus         A         B         C         D   E
# one    0.352693  0.450121  0.056892  0.777959 NaN
# two    0.458146  0.192793  0.532345  0.938560 NaN
# three  0.342202  0.112947  0.979487  0.108852 NaN
# four   0.028236  0.719497  0.954952  0.004119 NaN
# five   0.662823  0.924540  0.871982  0.926860 NaN
# six    0.513706  0.027894  0.228887  0.290175 NaN

# %%
# df['E'] = 0.0

# %%
# df

# %%
### Identify maximun value and put on column 'MAX'

# %%
df['MAX'] = df.T.max()

# %%
df
# Out:
# Genus         A         B         C         D   E       MAX
# one    0.352693  0.450121  0.056892  0.777959 NaN  0.777959
# two    0.458146  0.192793  0.532345  0.938560 NaN  0.938560
# three  0.342202  0.112947  0.979487  0.108852 NaN  0.979487
# four   0.028236  0.719497  0.954952  0.004119 NaN  0.954952
# five   0.662823  0.924540  0.871982  0.926860 NaN  0.926860
# six    0.513706  0.027894  0.228887  0.290175 NaN  0.513706

# %%
df['ID'] = np.arange(6.)

# %%
df
# Out:
# Genus         A         B         C         D   E       MAX   ID
# one    0.352693  0.450121  0.056892  0.777959 NaN  0.777959  0.0
# two    0.458146  0.192793  0.532345  0.938560 NaN  0.938560  1.0
# three  0.342202  0.112947  0.979487  0.108852 NaN  0.979487  2.0
# four   0.028236  0.719497  0.954952  0.004119 NaN  0.954952  3.0
# five   0.662823  0.924540  0.871982  0.926860 NaN  0.926860  4.0
# six    0.513706  0.027894  0.228887  0.290175 NaN  0.513706  5.0

# %% [markdown]
# ### Identify Delta value and put on column 'x'

# %%
df.T.min()
# Out:
# one      0.000000
# two      0.192793
# three    0.108852
# four     0.004119
# five     0.662823
# six      0.027894
# dtype: float64

# %%
df['x'] = df.T.min()

# %%
df
# Out:
# Genus         A         B         C         D   E       MAX   ID         x
# one    0.352693  0.450121  0.056892  0.777959 NaN  0.777959  0.0  0.000000
# two    0.458146  0.192793  0.532345  0.938560 NaN  0.938560  1.0  0.192793
# three  0.342202  0.112947  0.979487  0.108852 NaN  0.979487  2.0  0.108852
# four   0.028236  0.719497  0.954952  0.004119 NaN  0.954952  3.0  0.004119
# five   0.662823  0.924540  0.871982  0.926860 NaN  0.926860  4.0  0.662823
# six    0.513706  0.027894  0.228887  0.290175 NaN  0.513706  5.0  0.027894

# %%
df
# Out:
# Genus         A         B         C         D   E       MAX   ID         x
# one    0.352693  0.450121  0.056892  0.777959 NaN  0.777959  0.0  0.000000
# two    0.458146  0.192793  0.532345  0.938560 NaN  0.938560  1.0  0.192793
# three  0.342202  0.112947  0.979487  0.108852 NaN  0.979487  2.0  0.108852
# four   0.028236  0.719497  0.954952  0.004119 NaN  0.954952  3.0  0.004119
# five   0.662823  0.924540  0.871982  0.926860 NaN  0.926860  4.0  0.662823
# six    0.513706  0.027894  0.228887  0.290175 NaN  0.513706  5.0  0.027894

# %%
df.drop('ID', axis='columns')
# Out:
# Genus         A         B         C         D   E       MAX         x
# one    0.352693  0.450121  0.056892  0.777959 NaN  0.777959  0.000000
# two    0.458146  0.192793  0.532345  0.938560 NaN  0.938560  0.192793
# three  0.342202  0.112947  0.979487  0.108852 NaN  0.979487  0.108852
# four   0.028236  0.719497  0.954952  0.004119 NaN  0.954952  0.004119
# five   0.662823  0.924540  0.871982  0.926860 NaN  0.926860  0.662823
# six    0.513706  0.027894  0.228887  0.290175 NaN  0.513706  0.027894

# %%
df
# Out:
# Genus         A         B         C         D   E       MAX   ID         x
# one    0.352693  0.450121  0.056892  0.777959 NaN  0.777959  0.0  0.000000
# two    0.458146  0.192793  0.532345  0.938560 NaN  0.938560  1.0  0.192793
# three  0.342202  0.112947  0.979487  0.108852 NaN  0.979487  2.0  0.108852
# four   0.028236  0.719497  0.954952  0.004119 NaN  0.954952  3.0  0.004119
# five   0.662823  0.924540  0.871982  0.926860 NaN  0.926860  4.0  0.662823
# six    0.513706  0.027894  0.228887  0.290175 NaN  0.513706  5.0  0.027894

# %% [markdown]
# ## Inplace manupulation

# %%
df.drop(['ID','E'], axis='columns', inplace=True)
df
# Out:
# Genus         A         B         C         D       MAX         x
# one    0.352693  0.450121  0.056892  0.777959  0.777959  0.000000
# two    0.458146  0.192793  0.532345  0.938560  0.938560  0.192793
# three  0.342202  0.112947  0.979487  0.108852  0.979487  0.108852
# four   0.028236  0.719497  0.954952  0.004119  0.954952  0.004119
# five   0.662823  0.924540  0.871982  0.926860  0.926860  0.662823
# six    0.513706  0.027894  0.228887  0.290175  0.513706  0.027894

# %% [markdown]
# ## Change Index name

# %%
### df.reindex(columns=['A','B','C','D','MAX','MIN'])
df.reindex(columns=['A','B','C','D','MAX','MIN'])
# Out:
# Genus         A         B         C         D       MAX  MIN
# one    0.352693  0.450121  0.056892  0.777959  0.777959  NaN
# two    0.458146  0.192793  0.532345  0.938560  0.938560  NaN
# three  0.342202  0.112947  0.979487  0.108852  0.979487  NaN
# four   0.028236  0.719497  0.954952  0.004119  0.954952  NaN
# five   0.662823  0.924540  0.871982  0.926860  0.926860  NaN
# six    0.513706  0.027894  0.228887  0.290175  0.513706  NaN

# %% [markdown]
# - Column df['MIN'] is created with NaN because it does not exist.

# %% [markdown]
# ### Change Column index name

# %%
columns = df.columns
columns
# Out:
# Index(['A', 'B', 'C', 'D', 'MAX', 'x'], dtype='object', name='Genus')

# %%
index = df.index
index
# Out:
# Index(['one', 'two', 'three', 'four', 'five', 'six'], dtype='object')

# %%
# Rename column 'x' to 'MIN'
df.rename(columns={'x':'MIN'}, inplace=True)

# %%
df
# Out:
# Genus         A         B         C         D       MAX       MIN
# one    0.352693  0.450121  0.056892  0.777959  0.777959  0.000000
# two    0.458146  0.192793  0.532345  0.938560  0.938560  0.192793
# three  0.342202  0.112947  0.979487  0.108852  0.979487  0.108852
# four   0.028236  0.719497  0.954952  0.004119  0.954952  0.004119
# five   0.662823  0.924540  0.871982  0.926860  0.926860  0.662823
# six    0.513706  0.027894  0.228887  0.290175  0.513706  0.027894

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'MAX', 'MIN'], dtype='object', name='Genus')

# %%
df.loc[:,['B','D','MAX','MIN']]
# Out:
# Genus         B         D       MAX       MIN
# one    0.450121  0.777959  0.777959  0.000000
# two    0.192793  0.938560  0.938560  0.192793
# three  0.112947  0.108852  0.979487  0.108852
# four   0.719497  0.004119  0.954952  0.004119
# five   0.924540  0.926860  0.926860  0.662823
# six    0.027894  0.290175  0.513706  0.027894

# %%
df
# Out:
# Genus         A         B         C         D       MAX       MIN
# one    0.352693  0.450121  0.056892  0.777959  0.777959  0.000000
# two    0.458146  0.192793  0.532345  0.938560  0.938560  0.192793
# three  0.342202  0.112947  0.979487  0.108852  0.979487  0.108852
# four   0.028236  0.719497  0.954952  0.004119  0.954952  0.004119
# five   0.662823  0.924540  0.871982  0.926860  0.926860  0.662823
# six    0.513706  0.027894  0.228887  0.290175  0.513706  0.027894

# %%
df.drop('MIN', axis='columns', inplace=True)

# %%
df
# Out:
# Genus         A         B         C         D       MAX
# one    0.352693  0.450121  0.056892  0.777959  0.777959
# two    0.458146  0.192793  0.532345  0.938560  0.938560
# three  0.342202  0.112947  0.979487  0.108852  0.979487
# four   0.028236  0.719497  0.954952  0.004119  0.954952
# five   0.662823  0.924540  0.871982  0.926860  0.926860
# six    0.513706  0.027894  0.228887  0.290175  0.513706

# %%
df.shape
# Out:
# (6, 5)

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'MAX'], dtype='object', name='Genus')

# %%
df.index
# Out:
# Index(['one', 'two', 'three', 'four', 'five', 'six'], dtype='object')

# %%
df.min()
# Out:
# Genus
# A      0.028236
# B      0.027894
# C      0.056892
# D      0.004119
# MAX    0.513706
# dtype: float64

# %%
df['MIN'] = df.T.min()

# %%
df
# Out:
# Genus         A         B         C         D       MAX       MIN
# one    0.352693  0.450121  0.056892  0.777959  0.777959  0.056892
# two    0.458146  0.192793  0.532345  0.938560  0.938560  0.192793
# three  0.342202  0.112947  0.979487  0.108852  0.979487  0.108852
# four   0.028236  0.719497  0.954952  0.004119  0.954952  0.004119
# five   0.662823  0.924540  0.871982  0.926860  0.926860  0.662823
# six    0.513706  0.027894  0.228887  0.290175  0.513706  0.027894

# %% [markdown]
# ## SUM Calculations

# %% [markdown]
# ### SUM of index (sum of A, sum of B, Sum of C....)

# %%
df.sum(axis='index', skipna = True) #df.sum(axis=0, skipna = True)
# Out:
# Genus
# A      2.357806
# B      2.427792
# C      3.624546
# D      3.046526
# MAX    5.091524
# MIN    1.053374
# dtype: float64

# %% [markdown]
# ### SUM of column (Sum of one, Sum of two, Sum of three, ...)

# %%
df.sum(axis='columns', skipna = True) #df.sum(axis=1, skipna = True)
# Out:
# one      2.472517
# two      3.253197
# three    2.631826
# four     2.665874
# five     4.975889
# six      1.602262
# dtype: float64

# %% [markdown]
# ### TOTAL of columns by each index

# %%
df.loc[:,['A','B','C','D']]
# Out:
# Genus         A         B         C         D
# one    0.352693  0.450121  0.056892  0.777959
# two    0.458146  0.192793  0.532345  0.938560
# three  0.342202  0.112947  0.979487  0.108852
# four   0.028236  0.719497  0.954952  0.004119
# five   0.662823  0.924540  0.871982  0.926860
# six    0.513706  0.027894  0.228887  0.290175

# %%
df['TOTAL'] = df.loc[:,['A','B','C','D']].sum(axis='columns', skipna = True)

# %%
df
# Out:
# Genus         A         B         C         D       MAX       MIN     TOTAL
# one    0.352693  0.450121  0.056892  0.777959  0.777959  0.056892  1.637666
# two    0.458146  0.192793  0.532345  0.938560  0.938560  0.192793  2.121844
# three  0.342202  0.112947  0.979487  0.108852  0.979487  0.108852  1.543488
# four   0.028236  0.719497  0.954952  0.004119  0.954952  0.004119  1.706803
# five   0.662823  0.924540  0.871982  0.926860  0.926860  0.662823  3.386206
# six    0.513706  0.027894  0.228887  0.290175  0.513706  0.027894  1.060662

# %%
df.shape
# Out:
# (6, 7)

# %%
df.info
# Out:
# <bound method DataFrame.info of Genus         A         B         C         D       MAX       MIN     TOTAL
# one    0.352693  0.450121  0.056892  0.777959  0.777959  0.056892  1.637666
# two    0.458146  0.192793  0.532345  0.938560  0.938560  0.192793  2.121844
# three  0.342202  0.112947  0.979487  0.108852  0.979487  0.108852  1.543488
# four   0.028236  0.719497  0.954952  0.004119  0.954952  0.004119  1.706803
# five   0.662823  0.924540  0.871982  0.926860  0.926860  0.662823  3.386206
# six    0.513706  0.027894  0.228887  0.290175  0.513706  0.027894  1.060662>

# %%
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
