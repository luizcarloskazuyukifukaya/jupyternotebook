# %% [markdown]
# # Pandas Data Manupulation

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Sample Data

# %%
df = pd.DataFrame(np.random.rand(6,4),
                 index=['one', 'two', 'three', 'four', 'five', 'six'],
                 columns=pd.Index(['A', 'B', 'C', 'D'],
                                 name='Genus'))

# %%
df
# Out:
# Genus         A         B         C         D
# one    0.640265  0.020242  0.846432  0.280030
# two    0.494422  0.984032  0.997130  0.930910
# three  0.335315  0.933638  0.471824  0.402037
# four   0.933134  0.661767  0.850760  0.352793
# five   0.353186  0.291667  0.875396  0.885243
# six    0.649510  0.698741  0.196590  0.216939

# %%
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Statistic Calculation
# https://pandas.pydata.org/pandas－docs/stable/reference/api/pandas.DataFrame.max.htmlhttps://pandas.pydata.org/pandas－docs/stable/referhttps://pandas.pydata.org/pandas－docs/stable/refer

# %% [markdown]
# ### Extract the max value for each column

# %%
df.max()
# Out:
# Genus
# A    0.933134
# B    0.984032
# C    0.997130
# D    0.930910
# dtype: float64

# %% [markdown]
# ### Extract the max value of one specific column

# %%
df.max()
# Out:
# Genus
# A    0.933134
# B    0.984032
# C    0.997130
# D    0.930910
# dtype: float64

# %% [markdown]
# ### Extract the max value of a specific column

# %%
df['A'].max() # Max of "A' column
# Out:
# 0.9331340329581247

# %% [markdown]
# ## Add new column

# %%
df['E'] = np.nan

# %%
df
# Out:
# Genus         A         B         C         D   E
# one    0.640265  0.020242  0.846432  0.280030 NaN
# two    0.494422  0.984032  0.997130  0.930910 NaN
# three  0.335315  0.933638  0.471824  0.402037 NaN
# four   0.933134  0.661767  0.850760  0.352793 NaN
# five   0.353186  0.291667  0.875396  0.885243 NaN
# six    0.649510  0.698741  0.196590  0.216939 NaN

# %%
df['E'] = 0.0

# %%
df
# Out:
# Genus         A         B         C         D    E
# one    0.640265  0.020242  0.846432  0.280030  0.0
# two    0.494422  0.984032  0.997130  0.930910  0.0
# three  0.335315  0.933638  0.471824  0.402037  0.0
# four   0.933134  0.661767  0.850760  0.352793  0.0
# five   0.353186  0.291667  0.875396  0.885243  0.0
# six    0.649510  0.698741  0.196590  0.216939  0.0

# %%
### Identify maximun value and put on column 'MAX'

# %%
df['MAX'] = df.T.max()

# %%
df
# Out:
# Genus         A         B         C         D    E       MAX
# one    0.640265  0.020242  0.846432  0.280030  0.0  0.846432
# two    0.494422  0.984032  0.997130  0.930910  0.0  0.997130
# three  0.335315  0.933638  0.471824  0.402037  0.0  0.933638
# four   0.933134  0.661767  0.850760  0.352793  0.0  0.933134
# five   0.353186  0.291667  0.875396  0.885243  0.0  0.885243
# six    0.649510  0.698741  0.196590  0.216939  0.0  0.698741

# %%
df['ID'] = np.arange(6.)

# %%
df
# Out:
# Genus         A         B         C         D    E       MAX
# one    0.640265  0.020242  0.846432  0.280030  0.0  0.846432
# two    0.494422  0.984032  0.997130  0.930910  1.0  0.997130
# three  0.335315  0.933638  0.471824  0.402037  2.0  0.933638
# four   0.933134  0.661767  0.850760  0.352793  3.0  0.933134
# five   0.353186  0.291667  0.875396  0.885243  4.0  0.885243
# six    0.649510  0.698741  0.196590  0.216939  5.0  0.698741

# %% [markdown]
# ### Identify Delta value and put on column 'x'

# %%
df.T.min()

# %%
df['x'] = df.T.min()

# %%
df
# Out:
# Genus         A         B         C         D    E       MAX         x
# one    0.640265  0.020242  0.846432  0.280030  0.0  0.846432  0.000000
# two    0.494422  0.984032  0.997130  0.930910  1.0  1.000000  0.494422
# three  0.335315  0.933638  0.471824  0.402037  2.0  2.000000  0.335315
# four   0.933134  0.661767  0.850760  0.352793  3.0  3.000000  0.352793
# five   0.353186  0.291667  0.875396  0.885243  4.0  4.000000  0.291667
# six    0.649510  0.698741  0.196590  0.216939  5.0  5.000000  0.196590

# %%
# Out:
# one      0.846432
# two      1.000000
# three    2.000000
# four     3.000000
# five     4.000000
# six      5.000000
# dtype: float64
